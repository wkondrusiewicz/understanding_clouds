# %%
import pandas as pd
import os
from understanding_clouds.utils import show_mask, preproces_dataframe

# %%
data_location = '../../data'

# %%
df = pd.read_csv(os.path.join(data_location, 'train.csv'))

# %%
df = preproces_dataframe(df)

# %%
df.head()
# Out:
#           Image_Label                                      EncodedPixels  \
# 0    0011165.jpg_Fish  264918 937 266318 937 267718 937 269118 937 27...
# 1  0011165.jpg_Flower  1355565 1002 1356965 1002 1358365 1002 1359765...
# 2  0011165.jpg_Gravel                                                NaN
# 3   0011165.jpg_Sugar                                                NaN
# 4    002be4f.jpg_Fish  233813 878 235213 878 236613 878 238010 881 23...
#
#       filename mask_type
# 0  0011165.jpg      Fish
# 1  0011165.jpg    Flower
# 2  0011165.jpg    Gravel
# 3  0011165.jpg     Sugar
# 4  002be4f.jpg      Fish

# %%
show_mask(df, 100, os.path.join(data_location, 'train_images'))
