# %%
import pandas as pd
import numpy as np
import os
import cv2
from understanding_clouds.utils import show_mask, show_masks_and_img, preproces_dataframe_single_mask, get_mask_and_img, get_all_masks_and_img, preproces_dataframe_all_masks

# %%
data_location = '../data'

# %%
df = pd.read_csv(os.path.join(data_location, 'train.csv'))

# %%
df = preproces_dataframe_all_masks(df)

# %%
masks, img, labels = get_all_masks_and_img(df, 123, os.path.join(data_location, 'train_images'))

# %%
show_masks_and_img(masks, img, labels)
